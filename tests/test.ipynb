# %%
import sys
import os

# Add the project root (one level up from tests/) to sys.path
sys.path.append(os.path.abspath(".."))

# Now use an absolute import (no leading dot)
from app.modules.pipeline.pipeline import embedding_node, Organisations, customer
import uuid

# %%
Organisations
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): mermaid.ink:443
# DEBUG:urllib3.connectionpool:https://mermaid.ink:443 "GET ...?type=png&bgColor=!white HTTP/1.1" 200 12457

# %%
customer
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): mermaid.ink:443
# DEBUG:urllib3.connectionpool:https://mermaid.ink:443 "GET ...?type=png&bgColor=!white HTTP/1.1" 200 6408
